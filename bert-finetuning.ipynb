# %% [markdown]
# # BERT fine-tuning
# This notebook uses a roBERTa model pre-trained on twitter data for the task of sentiment analysis.
# Starting from this base model, we fine-tune either just the parameters of the output layer, or the ones of the output layer and the Layer norms.

# %% [markdown]
# ### Imports and setup

# %%
import os
import torch
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, log_loss, roc_auc_score
from typing import Callable, Dict
import logging


os.environ["WANDB_DISABLED"] = "true"

# %% [markdown]
# ### Evaluation methods

# %%
def _log_metrics(metrics):
  logging.info(
    '---\n' +
    '\n'.join([f'* {x}: {y}' for x,y in metrics.items()]) +
    '\n---'
  )


def evaluate_prob(y: np.array, y_pred: np.array, verbose=True) -> Dict[str, float]:
  """
  Returns BCE loss, AUC in this order.
  """

  bce = log_loss(y, y_pred)
  auc = roc_auc_score(y, y_pred)
  result = {'bce': bce, 'auc': auc}

  if verbose:
    _log_metrics(result)
  return result


def evaluate(y: np.array, y_pred: np.array) -> Dict[str, float]:
  """
  Returns accuracy, precision, recall, F1, BCE loss, AUC in this order.

  * accuracy: proportion of correctly classified answers
  * precision: proportion of correctly classified positives
  * recall: proportion of actual positives correctly classified
  * F1: combination of precision & recall
  """

  accuracy = accuracy_score(y, y_pred)
  precision = precision_score(y, y_pred)
  recall = recall_score(y, y_pred)
  f1 = f1_score(y, y_pred)
  # prob_metrics = evaluate_prob(y, y_pred, verbose=False)
  result = {'accuracy': accuracy, 'precision': precision, 'recall': recall, 'f1': f1}

  _log_metrics(result)
  return result


def evaluate_model(model: Callable[[pd.DataFrame], np.array], df: pd.DataFrame) -> Dict[str, float]:
  """
  Expects a dataframe with columns `x` and `y`.
  """

  y = df['y'].to_numpy()
  y_pred = model(df)

  return evaluate(y, y_pred)

# %% [markdown]
# ### Preprocessing methods

# %%
from typing import Dict, Optional
import pandas as pd
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import WhitespaceTokenizer
from nltk.corpus import stopwords
from textblob import Word
from tqdm import tqdm

nltk.download('stopwords')
nltk.download('omw-1.4')
stop_words = set(stopwords.words('english'))

nltk.download('wordnet')
tokenizer = WhitespaceTokenizer()
lemmatizer = WordNetLemmatizer()

tqdm.pandas()

def to_lower(df: pd.DataFrame, x_col='x'):
  """
  To be applied to a dataframe with a column called 'x' that contains sentences.
  """
  df[x_col] = df[x_col].apply(lambda sentence: sentence.lower())

def tokenize(df: pd.DataFrame, x_col='x'):
  """
  To be applied to a dataframe with a column called 'x' that contains sentences.
  """
  df[x_col] = df[x_col].apply(lambda sentence: tokenizer.tokenize(sentence))

def remove_tags(df: pd.DataFrame, x_col='x'):
  """
  To be applied to a dataframe with a column called 'x' that contains sentences.
  Deprecated in favour of remove_tag_tokens(df: pd.DataFrame)
  """
  df[x_col] = df[x_col].apply(lambda sentence: sentence.replace('<user>', '').replace('<url>', '').strip())

def remove_tag_tokens(df: pd.DataFrame, x_col='x'):
  """
  To be applied to a dataframe with a column called 'x' that contains tokens.
  """
  df[x_col] = df[x_col].apply(lambda tokens: [w for w in tokens if not w in ['user', '<url>']])

def remove_stopwords(df: pd.DataFrame, x_col='x'):
  """
  To be applied to a dataframe with a column called 'x' that contains tokens.
  """
  df[x_col] = df[x_col].apply(lambda tokens: [w for w in tokens if not w in stop_words])

def lemmatize(df: pd.DataFrame, x_col='x'):
  """
  To be applied to a dataframe with a column called 'x' that contains tokens.
  """
  df[x_col] = df[x_col].apply(lambda tokens: [lemmatizer.lemmatize(w) for w in tokens])

def remove_single_symbols(df: pd.DataFrame, x_col='x'):
  """
  To be applied to a dataframe with a column called 'x' that contains tokens.
  """
  df[x_col] = df[x_col].apply(lambda tokens: [w for w in tokens if len(w) > 1])

def spelling_correction(df: pd.DataFrame, x_col='x'):
  """
  To be applied to a dataframe with a column called 'x' that contains tokens.
  """
  df[x_col] = df[x_col].progress_apply(lambda tokens: [Word(w).correct() for w in tokens])


def replace_user_handles(df: pd.DataFrame, x_col='x'):
  """
  To be applied to a dataframe with a column called 'x' that contains tokens.
  """
  df[x_col] = df[x_col].apply(lambda tokens: [w if not (w.startswith("@") and len(w) > 1) else "<user>" for w in tokens])

def replace_urls(df: pd.DataFrame, x_col='x'):
  """
  To be applied to a dataframe with a column called 'x' that contains tokens.
  """
  df[x_col] = df[x_col].apply(lambda tokens: [w if not (w.startswith("http://") or w.startswith("https://") or w.startswith("www.")) else "<url>" for w in tokens])

def untokenize(df: pd.DataFrame, x_col='x'):
  """
  To be applied to a dataframe with a column called 'x' that contains tokens.
  """
  df[x_col] = df[x_col].apply(lambda tokens: " ".join(tokens))

def preprocess(df: pd.DataFrame, flags: Optional[Dict[str, bool]], x_col='x'):
  if flags is not None:
    if flags.get('to_lower', False):
      to_lower(df, x_col=x_col)
    if flags.get('tokenize', False):
      tokenize(df, x_col=x_col)
    if flags.get('replace_user_handles', False):
      replace_user_handles(df, x_col=x_col)
    if flags.get('replace_urls', False):
      replace_urls(df, x_col=x_col)  
    if flags.get('remove_tags', False):
      remove_tags(df, x_col=x_col)
    if flags.get('remove_tag_tokens', False):
      remove_tag_tokens(df, x_col=x_col)
    if flags.get('remove_stopwords', False):
      remove_stopwords(df, x_col=x_col)
    if flags.get('lemmatize', False):
      lemmatize(df, x_col=x_col)
    if flags.get('remove_single_symbols', False):
      remove_single_symbols(df, x_col=x_col)
    if flags.get('spelling_correction', False):
      spelling_correction(df, x_col=x_col)
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /usr/share/nltk_data...
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ### Methods to get and prepare the dataset, the base model, compute the metrics, and train the model

# %%
from pathlib import Path
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer
from datasets import Dataset, ClassLabel
from scipy.special import softmax


def prepare_dataset(df, preprocessing=None):
  preprocess(df, flags=preprocessing, x_col='text')
  dataset = Dataset.from_pandas(df)

  new_features = dataset.features.copy()
  new_features['label'] = ClassLabel(names=['0', '1'])

  dataset = dataset.cast(new_features)
  return dataset


def tokenize(ds, tokenizer, path=None, force=True):
  def tokenize_function(ds):
    return tokenizer(ds['text'], padding=True, truncation=True)

  def load_or_tokenize(ds, path, force):
    if not force and path is not None and Path(path).exists():
      return Dataset.load_from_disk(path)
    else:
      ds_tokenized = ds.map(tokenize_function, batched=True)
      if path is not None:
        ds_tokenized.save_to_disk(path)
      return ds_tokenized

  return load_or_tokenize(ds, path=path, force=force)


def get_BERT(model_name, device):
  model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2, ignore_mismatched_sizes=True).to(device)
  model.save_pretrained(model_name)
  return model


def compute_metrics(eval_pred):
  predictions, labels = eval_pred

  point_estimates = np.argmax(predictions, axis=1)
  point_estimate_eval = evaluate(labels, point_estimates)

  prob_estimates = softmax(predictions, axis=1)[:, 1]
  prob_estimates_eval = evaluate_prob(labels, prob_estimates)
  confidence = np.max(softmax(predictions, axis=1), axis=1)
  all_confidence = confidence.mean()
  all_confidence_std = confidence.std()
  correct_confidence = confidence[labels == point_estimates].mean()
  correct_confidence_std = confidence[labels == point_estimates].std()
  incorrect_confidence = confidence[labels != point_estimates].mean()
  incorrect_confidence_std = confidence[labels != point_estimates].std()

  return {
    **point_estimate_eval,
    **prob_estimates_eval,
    'confidence': all_confidence,
    'confidence_std': all_confidence_std,
    'correct_confidence': correct_confidence,
    'correct_confidence_std': correct_confidence_std,
    'incorrect_confidence': incorrect_confidence,
    'incorrect_confidence_std': incorrect_confidence_std,
  }


def train(model_name, tokenizer_name, device, df_train, df_val, preprocessing=None, batch_size=32, epochs=1, force_tokenize=True, train_LN=True):
  dataset_train = prepare_dataset(df_train, preprocessing=preprocessing)
  dataset_val = prepare_dataset(df_val, preprocessing=preprocessing)

  tokenizer = AutoTokenizer.from_pretrained(tokenizer_name)
  train_tokenized = tokenize(
    dataset_train,
    tokenizer,
    force=force_tokenize)
  val_tokenized = tokenize(
    dataset_val,
    tokenizer,
    force=force_tokenize)

  model = get_BERT(model_name, device)
  for param in model.parameters():
    param.requires_grad = False

  for param in model.classifier.parameters():
    param.requires_grad = True

  if train_LN:
    n_params = set_trainable(model)

  training_args = TrainingArguments(
    output_dir='bert_data/test_trainer',
    num_train_epochs=epochs,
    save_strategy='epoch',
    evaluation_strategy='epoch',
    per_device_train_batch_size=batch_size,
    load_best_model_at_end=True,
    metric_for_best_model='accuracy',
    greater_is_better=True)

  trainer = Trainer(
    model,
    training_args,
    train_dataset=train_tokenized,
    eval_dataset=val_tokenized,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics)

  trainer.train()

  val_pred = trainer.predict(val_tokenized)
  y_pred = np.argmax(val_pred.predictions, axis=1)
  y = val_tokenized.to_pandas()['label']
  metrics = evaluate(y, y_pred)

  return model

# %% [markdown]
# Loading of the training and evaluation data; methods to select a subset of the data.

# %%
import pandas as pd

DF_TRAIN = pd.read_csv('../input/twittersentiment/train.csv')[['index', 'text', 'label']]
DF_EVAL = pd.read_csv('../input/twittersentiment/test.csv')[['index', 'text', 'label']]


def select_train(size=160_000):
  df = DF_TRAIN
  if size is not None:
    df = df.iloc[:size]
  return df


def select_eval(size=40_000):
  df = DF_EVAL
  if size is not None:
    df = df.iloc[:size]
  return df

# %% [markdown]
# Methods to set the layer norm parameters to trainable and display the model and parameters in a table.

# %%
import numpy as np
from prettytable import PrettyTable

def count_parameters(model):
    table = PrettyTable(["Modules", "Trainable Parameters", "Parameters"])
    total_params_train = 0
    total_params = 0
    for name, parameter in model.named_parameters():
        params = parameter.numel()
        params_t = params
        if not parameter.requires_grad:
            params_t = 0
        table.add_row([name, params_t, params])
        total_params_train += params_t
        total_params += params
    print(table)
    print(f"Total Trainable Params: {total_params_train}")
    pourcent = float(total_params_train)/total_params
    print(f"Percentage of trainable parameters: {pourcent}")

    return total_params_train, pourcent


def set_trainable(model):
    count = 0
    for name, parameter in model.named_parameters():
        if "layer_norm" in str(name) or "LayerNorm" in str(name):
            count += 1
            parameter.requires_grad = True

    print(count)
    return count_parameters(model)[0]

# %% [markdown]
# ---

# %% [markdown]
# ## Training and evaluation of the model
# Set `train_LN` to False if you wish to only train the output layer.

# %%
logging.basicConfig(level=logging.INFO)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
MODEL = 'cardiffnlp/twitter-roberta-base-sentiment-latest'
TOKENIZER = 'cardiffnlp/twitter-roberta-base-sentiment-latest'

EPOCHS = 5
BATCH_SIZE = 32
TRAIN_LN = True

# %%
df_train = select_train()
df_eval = select_eval()
model = train(MODEL, TOKENIZER, device, df_train, df_eval, batch_size=BATCH_SIZE, epochs=EPOCHS, train_LN=TRAIN_LN)
# Out:
# Casting the dataset:   0%|          | 0/16 [00:00<?, ?ba/s]
# Casting the dataset:   0%|          | 0/4 [00:00<?, ?ba/s]
# Downloading:   0%|          | 0.00/929 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
#   0%|          | 0/160 [00:00<?, ?ba/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
#   0%|          | 0/40 [00:00<?, ?ba/s]
# Downloading:   0%|          | 0.00/478M [00:00<?, ?B/s]
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest and are newly initialized because the shapes did not match:
# - classifier.out_proj.weight: found shape torch.Size([3, 768]) in the checkpoint and torch.Size([2, 768]) in the model instantiated
# - classifier.out_proj.bias: found shape torch.Size([3]) in the checkpoint and torch.Size([2]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using the `WAND_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# The following columns in the training set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: text, index. If text, index are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# /opt/conda/lib/python3.7/site-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 160000
#   Num Epochs = 5
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 25000
# 50
# +------------------------------------------------------------+----------------------+------------+
# |                          Modules                           | Trainable Parameters | Parameters |
# +------------------------------------------------------------+----------------------+------------+
# |         roberta.embeddings.word_embeddings.weight          |          0           |  38603520  |
# |       roberta.embeddings.position_embeddings.weight        |          0           |   394752   |
# |      roberta.embeddings.token_type_embeddings.weight       |          0           |    768     |
# |            roberta.embeddings.LayerNorm.weight             |         768          |    768     |
# |             roberta.embeddings.LayerNorm.bias              |         768          |    768     |
# |    roberta.encoder.layer.0.attention.self.query.weight     |          0           |   589824   |
# |     roberta.encoder.layer.0.attention.self.query.bias      |          0           |    768     |
# |     roberta.encoder.layer.0.attention.self.key.weight      |          0           |   589824   |
# |      roberta.encoder.layer.0.attention.self.key.bias       |          0           |    768     |
# |    roberta.encoder.layer.0.attention.self.value.weight     |          0           |   589824   |
# |     roberta.encoder.layer.0.attention.self.value.bias      |          0           |    768     |
# |   roberta.encoder.layer.0.attention.output.dense.weight    |          0           |   589824   |
# |    roberta.encoder.layer.0.attention.output.dense.bias     |          0           |    768     |
# | roberta.encoder.layer.0.attention.output.LayerNorm.weight  |         768          |    768     |
# |  roberta.encoder.layer.0.attention.output.LayerNorm.bias   |         768          |    768     |
# |     roberta.encoder.layer.0.intermediate.dense.weight      |          0           |  2359296   |
# |      roberta.encoder.layer.0.intermediate.dense.bias       |          0           |    3072    |
# |        roberta.encoder.layer.0.output.dense.weight         |          0           |  2359296   |
# |         roberta.encoder.layer.0.output.dense.bias          |          0           |    768     |
# |      roberta.encoder.layer.0.output.LayerNorm.weight       |         768          |    768     |
# |       roberta.encoder.layer.0.output.LayerNorm.bias        |         768          |    768     |
# |    roberta.encoder.layer.1.attention.self.query.weight     |          0           |   589824   |
# |     roberta.encoder.layer.1.attention.self.query.bias      |          0           |    768     |
# |     roberta.encoder.layer.1.attention.self.key.weight      |          0           |   589824   |
# |      roberta.encoder.layer.1.attention.self.key.bias       |          0           |    768     |
# |    roberta.encoder.layer.1.attention.self.value.weight     |          0           |   589824   |
# |     roberta.encoder.layer.1.attention.self.value.bias      |          0           |    768     |
# |   roberta.encoder.layer.1.attention.output.dense.weight    |          0           |   589824   |
# |    roberta.encoder.layer.1.attention.output.dense.bias     |          0           |    768     |
# | roberta.encoder.layer.1.attention.output.LayerNorm.weight  |         768          |    768     |
# |  roberta.encoder.layer.1.attention.output.LayerNorm.bias   |         768          |    768     |
# |     roberta.encoder.layer.1.intermediate.dense.weight      |          0           |  2359296   |
# |      roberta.encoder.layer.1.intermediate.dense.bias       |          0           |    3072    |
# |        roberta.encoder.layer.1.output.dense.weight         |          0           |  2359296   |
# |         roberta.encoder.layer.1.output.dense.bias          |          0           |    768     |
# |      roberta.encoder.layer.1.output.LayerNorm.weight       |         768          |    768     |
# |       roberta.encoder.layer.1.output.LayerNorm.bias        |         768          |    768     |
# |    roberta.encoder.layer.2.attention.self.query.weight     |          0           |   589824   |
# |     roberta.encoder.layer.2.attention.self.query.bias      |          0           |    768     |
# |     roberta.encoder.layer.2.attention.self.key.weight      |          0           |   589824   |
# |      roberta.encoder.layer.2.attention.self.key.bias       |          0           |    768     |
# |    roberta.encoder.layer.2.attention.self.value.weight     |          0           |   589824   |
# |     roberta.encoder.layer.2.attention.self.value.bias      |          0           |    768     |
# |   roberta.encoder.layer.2.attention.output.dense.weight    |          0           |   589824   |
# |    roberta.encoder.layer.2.attention.output.dense.bias     |          0           |    768     |
# | roberta.encoder.layer.2.attention.output.LayerNorm.weight  |         768          |    768     |
# |  roberta.encoder.layer.2.attention.output.LayerNorm.bias   |         768          |    768     |
# |     roberta.encoder.layer.2.intermediate.dense.weight      |          0           |  2359296   |
# |      roberta.encoder.layer.2.intermediate.dense.bias       |          0           |    3072    |
# |        roberta.encoder.layer.2.output.dense.weight         |          0           |  2359296   |
# |         roberta.encoder.layer.2.output.dense.bias          |          0           |    768     |
# |      roberta.encoder.layer.2.output.LayerNorm.weight       |         768          |    768     |
# |       roberta.encoder.layer.2.output.LayerNorm.bias        |         768          |    768     |
# |    roberta.encoder.layer.3.attention.self.query.weight     |          0           |   589824   |
# |     roberta.encoder.layer.3.attention.self.query.bias      |          0           |    768     |
# |     roberta.encoder.layer.3.attention.self.key.weight      |          0           |   589824   |
# |      roberta.encoder.layer.3.attention.self.key.bias       |          0           |    768     |
# |    roberta.encoder.layer.3.attention.self.value.weight     |          0           |   589824   |
# |     roberta.encoder.layer.3.attention.self.value.bias      |          0           |    768     |
# |   roberta.encoder.layer.3.attention.output.dense.weight    |          0           |   589824   |
# |    roberta.encoder.layer.3.attention.output.dense.bias     |          0           |    768     |
# | roberta.encoder.layer.3.attention.output.LayerNorm.weight  |         768          |    768     |
# |  roberta.encoder.layer.3.attention.output.LayerNorm.bias   |         768          |    768     |
# |     roberta.encoder.layer.3.intermediate.dense.weight      |          0           |  2359296   |
# |      roberta.encoder.layer.3.intermediate.dense.bias       |          0           |    3072    |
# |        roberta.encoder.layer.3.output.dense.weight         |          0           |  2359296   |
# |         roberta.encoder.layer.3.output.dense.bias          |          0           |    768     |
# |      roberta.encoder.layer.3.output.LayerNorm.weight       |         768          |    768     |
# |       roberta.encoder.layer.3.output.LayerNorm.bias        |         768          |    768     |
# |    roberta.encoder.layer.4.attention.self.query.weight     |          0           |   589824   |
# |     roberta.encoder.layer.4.attention.self.query.bias      |          0           |    768     |
# |     roberta.encoder.layer.4.attention.self.key.weight      |          0           |   589824   |
# |      roberta.encoder.layer.4.attention.self.key.bias       |          0           |    768     |
# |    roberta.encoder.layer.4.attention.self.value.weight     |          0           |   589824   |
# |     roberta.encoder.layer.4.attention.self.value.bias      |          0           |    768     |
# |   roberta.encoder.layer.4.attention.output.dense.weight    |          0           |   589824   |
# |    roberta.encoder.layer.4.attention.output.dense.bias     |          0           |    768     |
# | roberta.encoder.layer.4.attention.output.LayerNorm.weight  |         768          |    768     |
# |  roberta.encoder.layer.4.attention.output.LayerNorm.bias   |         768          |    768     |
# |     roberta.encoder.layer.4.intermediate.dense.weight      |          0           |  2359296   |
# |      roberta.encoder.layer.4.intermediate.dense.bias       |          0           |    3072    |
# |        roberta.encoder.layer.4.output.dense.weight         |          0           |  2359296   |
# |         roberta.encoder.layer.4.output.dense.bias          |          0           |    768     |
# |      roberta.encoder.layer.4.output.LayerNorm.weight       |         768          |    768     |
# |       roberta.encoder.layer.4.output.LayerNorm.bias        |         768          |    768     |
# |    roberta.encoder.layer.5.attention.self.query.weight     |          0           |   589824   |
# |     roberta.encoder.layer.5.attention.self.query.bias      |          0           |    768     |
# |     roberta.encoder.layer.5.attention.self.key.weight      |          0           |   589824   |
# |      roberta.encoder.layer.5.attention.self.key.bias       |          0           |    768     |
# |    roberta.encoder.layer.5.attention.self.value.weight     |          0           |   589824   |
# |     roberta.encoder.layer.5.attention.self.value.bias      |          0           |    768     |
# |   roberta.encoder.layer.5.attention.output.dense.weight    |          0           |   589824   |
# |    roberta.encoder.layer.5.attention.output.dense.bias     |          0           |    768     |
# | roberta.encoder.layer.5.attention.output.LayerNorm.weight  |         768          |    768     |
# |  roberta.encoder.layer.5.attention.output.LayerNorm.bias   |         768          |    768     |
# |     roberta.encoder.layer.5.intermediate.dense.weight      |          0           |  2359296   |
# |      roberta.encoder.layer.5.intermediate.dense.bias       |          0           |    3072    |
# |        roberta.encoder.layer.5.output.dense.weight         |          0           |  2359296   |
# |         roberta.encoder.layer.5.output.dense.bias          |          0           |    768     |
# |      roberta.encoder.layer.5.output.LayerNorm.weight       |         768          |    768     |
# |       roberta.encoder.layer.5.output.LayerNorm.bias        |         768          |    768     |
# |    roberta.encoder.layer.6.attention.self.query.weight     |          0           |   589824   |
# |     roberta.encoder.layer.6.attention.self.query.bias      |          0           |    768     |
# |     roberta.encoder.layer.6.attention.self.key.weight      |          0           |   589824   |
# |      roberta.encoder.layer.6.attention.self.key.bias       |          0           |    768     |
# |    roberta.encoder.layer.6.attention.self.value.weight     |          0           |   589824   |
# |     roberta.encoder.layer.6.attention.self.value.bias      |          0           |    768     |
# |   roberta.encoder.layer.6.attention.output.dense.weight    |          0           |   589824   |
# |    roberta.encoder.layer.6.attention.output.dense.bias     |          0           |    768     |
# | roberta.encoder.layer.6.attention.output.LayerNorm.weight  |         768          |    768     |
# |  roberta.encoder.layer.6.attention.output.LayerNorm.bias   |         768          |    768     |
# |     roberta.encoder.layer.6.intermediate.dense.weight      |          0           |  2359296   |
# |      roberta.encoder.layer.6.intermediate.dense.bias       |          0           |    3072    |
# |        roberta.encoder.layer.6.output.dense.weight         |          0           |  2359296   |
# |         roberta.encoder.layer.6.output.dense.bias          |          0           |    768     |
# |      roberta.encoder.layer.6.output.LayerNorm.weight       |         768          |    768     |
# |       roberta.encoder.layer.6.output.LayerNorm.bias        |         768          |    768     |
# |    roberta.encoder.layer.7.attention.self.query.weight     |          0           |   589824   |
# |     roberta.encoder.layer.7.attention.self.query.bias      |          0           |    768     |
# |     roberta.encoder.layer.7.attention.self.key.weight      |          0           |   589824   |
# |      roberta.encoder.layer.7.attention.self.key.bias       |          0           |    768     |
# |    roberta.encoder.layer.7.attention.self.value.weight     |          0           |   589824   |
# |     roberta.encoder.layer.7.attention.self.value.bias      |          0           |    768     |
# |   roberta.encoder.layer.7.attention.output.dense.weight    |          0           |   589824   |
# |    roberta.encoder.layer.7.attention.output.dense.bias     |          0           |    768     |
# | roberta.encoder.layer.7.attention.output.LayerNorm.weight  |         768          |    768     |
# |  roberta.encoder.layer.7.attention.output.LayerNorm.bias   |         768          |    768     |
# |     roberta.encoder.layer.7.intermediate.dense.weight      |          0           |  2359296   |
# |      roberta.encoder.layer.7.intermediate.dense.bias       |          0           |    3072    |
# |        roberta.encoder.layer.7.output.dense.weight         |          0           |  2359296   |
# |         roberta.encoder.layer.7.output.dense.bias          |          0           |    768     |
# |      roberta.encoder.layer.7.output.LayerNorm.weight       |         768          |    768     |
# |       roberta.encoder.layer.7.output.LayerNorm.bias        |         768          |    768     |
# |    roberta.encoder.layer.8.attention.self.query.weight     |          0           |   589824   |
# |     roberta.encoder.layer.8.attention.self.query.bias      |          0           |    768     |
# |     roberta.encoder.layer.8.attention.self.key.weight      |          0           |   589824   |
# |      roberta.encoder.layer.8.attention.self.key.bias       |          0           |    768     |
# |    roberta.encoder.layer.8.attention.self.value.weight     |          0           |   589824   |
# |     roberta.encoder.layer.8.attention.self.value.bias      |          0           |    768     |
# |   roberta.encoder.layer.8.attention.output.dense.weight    |          0           |   589824   |
# |    roberta.encoder.layer.8.attention.output.dense.bias     |          0           |    768     |
# | roberta.encoder.layer.8.attention.output.LayerNorm.weight  |         768          |    768     |
# |  roberta.encoder.layer.8.attention.output.LayerNorm.bias   |         768          |    768     |
# |     roberta.encoder.layer.8.intermediate.dense.weight      |          0           |  2359296   |
# |      roberta.encoder.layer.8.intermediate.dense.bias       |          0           |    3072    |
# |        roberta.encoder.layer.8.output.dense.weight         |          0           |  2359296   |
# |         roberta.encoder.layer.8.output.dense.bias          |          0           |    768     |
# |      roberta.encoder.layer.8.output.LayerNorm.weight       |         768          |    768     |
# |       roberta.encoder.layer.8.output.LayerNorm.bias        |         768          |    768     |
# |    roberta.encoder.layer.9.attention.self.query.weight     |          0           |   589824   |
# |     roberta.encoder.layer.9.attention.self.query.bias      |          0           |    768     |
# |     roberta.encoder.layer.9.attention.self.key.weight      |          0           |   589824   |
# |      roberta.encoder.layer.9.attention.self.key.bias       |          0           |    768     |
# |    roberta.encoder.layer.9.attention.self.value.weight     |          0           |   589824   |
# |     roberta.encoder.layer.9.attention.self.value.bias      |          0           |    768     |
# |   roberta.encoder.layer.9.attention.output.dense.weight    |          0           |   589824   |
# |    roberta.encoder.layer.9.attention.output.dense.bias     |          0           |    768     |
# | roberta.encoder.layer.9.attention.output.LayerNorm.weight  |         768          |    768     |
# |  roberta.encoder.layer.9.attention.output.LayerNorm.bias   |         768          |    768     |
# |     roberta.encoder.layer.9.intermediate.dense.weight      |          0           |  2359296   |
# |      roberta.encoder.layer.9.intermediate.dense.bias       |          0           |    3072    |
# |        roberta.encoder.layer.9.output.dense.weight         |          0           |  2359296   |
# |         roberta.encoder.layer.9.output.dense.bias          |          0           |    768     |
# |      roberta.encoder.layer.9.output.LayerNorm.weight       |         768          |    768     |
# |       roberta.encoder.layer.9.output.LayerNorm.bias        |         768          |    768     |
# |    roberta.encoder.layer.10.attention.self.query.weight    |          0           |   589824   |
# |     roberta.encoder.layer.10.attention.self.query.bias     |          0           |    768     |
# |     roberta.encoder.layer.10.attention.self.key.weight     |          0           |   589824   |
# |      roberta.encoder.layer.10.attention.self.key.bias      |          0           |    768     |
# |    roberta.encoder.layer.10.attention.self.value.weight    |          0           |   589824   |
# |     roberta.encoder.layer.10.attention.self.value.bias     |          0           |    768     |
# |   roberta.encoder.layer.10.attention.output.dense.weight   |          0           |   589824   |
# |    roberta.encoder.layer.10.attention.output.dense.bias    |          0           |    768     |
# | roberta.encoder.layer.10.attention.output.LayerNorm.weight |         768          |    768     |
# |  roberta.encoder.layer.10.attention.output.LayerNorm.bias  |         768          |    768     |
# |     roberta.encoder.layer.10.intermediate.dense.weight     |          0           |  2359296   |
# |      roberta.encoder.layer.10.intermediate.dense.bias      |          0           |    3072    |
# |        roberta.encoder.layer.10.output.dense.weight        |          0           |  2359296   |
# |         roberta.encoder.layer.10.output.dense.bias         |          0           |    768     |
# |      roberta.encoder.layer.10.output.LayerNorm.weight      |         768          |    768     |
# |       roberta.encoder.layer.10.output.LayerNorm.bias       |         768          |    768     |
# |    roberta.encoder.layer.11.attention.self.query.weight    |          0           |   589824   |
# |     roberta.encoder.layer.11.attention.self.query.bias     |          0           |    768     |
# |     roberta.encoder.layer.11.attention.self.key.weight     |          0           |   589824   |
# |      roberta.encoder.layer.11.attention.self.key.bias      |          0           |    768     |
# |    roberta.encoder.layer.11.attention.self.value.weight    |          0           |   589824   |
# |     roberta.encoder.layer.11.attention.self.value.bias     |          0           |    768     |
# |   roberta.encoder.layer.11.attention.output.dense.weight   |          0           |   589824   |
# |    roberta.encoder.layer.11.attention.output.dense.bias    |          0           |    768     |
# | roberta.encoder.layer.11.attention.output.LayerNorm.weight |         768          |    768     |
# |  roberta.encoder.layer.11.attention.output.LayerNorm.bias  |         768          |    768     |
# |     roberta.encoder.layer.11.intermediate.dense.weight     |          0           |  2359296   |
# |      roberta.encoder.layer.11.intermediate.dense.bias      |          0           |    3072    |
# |        roberta.encoder.layer.11.output.dense.weight        |          0           |  2359296   |
# |         roberta.encoder.layer.11.output.dense.bias         |          0           |    768     |
# |      roberta.encoder.layer.11.output.LayerNorm.weight      |         768          |    768     |
# |       roberta.encoder.layer.11.output.LayerNorm.bias       |         768          |    768     |
# |                  classifier.dense.weight                   |        589824        |   589824   |
# |                   classifier.dense.bias                    |         768          |    768     |
# |                 classifier.out_proj.weight                 |         1536         |    1536    |
# |                  classifier.out_proj.bias                  |          2           |     2      |
# +------------------------------------------------------------+----------------------+------------+
# Total Trainable Params: 630530
# Percentage of trainable parameters: 0.005058518376309707
#     <div>
#
#       <progress value='25000' max='25000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [25000/25000 1:20:47, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Bce</th>
#       <th>Auc</th>
#       <th>Confidence</th>
#       <th>Confidence Std</th>
#       <th>Correct Confidence</th>
#       <th>Correct Confidence Std</th>
#       <th>Incorrect Confidence</th>
#       <th>Incorrect Confidence Std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.329700</td>
#       <td>0.308614</td>
#       <td>0.866450</td>
#       <td>0.871013</td>
#       <td>0.860660</td>
#       <td>0.865806</td>
#       <td>0.308614</td>
#       <td>0.943056</td>
#       <td>0.890005</td>
#       <td>0.134136</td>
#       <td>0.911891</td>
#       <td>0.118058</td>
#       <td>0.748017</td>
#       <td>0.145018</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.312800</td>
#       <td>0.293247</td>
#       <td>0.872200</td>
#       <td>0.877169</td>
#       <td>0.865954</td>
#       <td>0.871526</td>
#       <td>0.293247</td>
#       <td>0.947629</td>
#       <td>0.885157</td>
#       <td>0.136730</td>
#       <td>0.907403</td>
#       <td>0.120732</td>
#       <td>0.733331</td>
#       <td>0.142749</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.304800</td>
#       <td>0.287420</td>
#       <td>0.876575</td>
#       <td>0.865952</td>
#       <td>0.891425</td>
#       <td>0.878504</td>
#       <td>0.287420</td>
#       <td>0.949487</td>
#       <td>0.894863</td>
#       <td>0.134078</td>
#       <td>0.916201</td>
#       <td>0.117503</td>
#       <td>0.743322</td>
#       <td>0.146262</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.297700</td>
#       <td>0.285683</td>
#       <td>0.878050</td>
#       <td>0.869805</td>
#       <td>0.889527</td>
#       <td>0.879556</td>
#       <td>0.285684</td>
#       <td>0.950206</td>
#       <td>0.895644</td>
#       <td>0.134801</td>
#       <td>0.916795</td>
#       <td>0.118492</td>
#       <td>0.743356</td>
#       <td>0.146640</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.298900</td>
#       <td>0.284905</td>
#       <td>0.878675</td>
#       <td>0.873535</td>
#       <td>0.885881</td>
#       <td>0.879665</td>
#       <td>0.284905</td>
#       <td>0.950482</td>
#       <td>0.895420</td>
#       <td>0.134714</td>
#       <td>0.916376</td>
#       <td>0.118718</td>
#       <td>0.743653</td>
#       <td>0.145922</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: text, index. If text, index are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 40000
#   Batch size = 8
# Saving model checkpoint to bert_data/test_trainer/checkpoint-5000
# Configuration saved in bert_data/test_trainer/checkpoint-5000/config.json
# Model weights saved in bert_data/test_trainer/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in bert_data/test_trainer/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in bert_data/test_trainer/checkpoint-5000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: text, index. If text, index are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 40000
#   Batch size = 8
# Saving model checkpoint to bert_data/test_trainer/checkpoint-10000
# Configuration saved in bert_data/test_trainer/checkpoint-10000/config.json
# Model weights saved in bert_data/test_trainer/checkpoint-10000/pytorch_model.bin
# tokenizer config file saved in bert_data/test_trainer/checkpoint-10000/tokenizer_config.json
# Special tokens file saved in bert_data/test_trainer/checkpoint-10000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: text, index. If text, index are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 40000
#   Batch size = 8
# Saving model checkpoint to bert_data/test_trainer/checkpoint-15000
# Configuration saved in bert_data/test_trainer/checkpoint-15000/config.json
# Model weights saved in bert_data/test_trainer/checkpoint-15000/pytorch_model.bin
# tokenizer config file saved in bert_data/test_trainer/checkpoint-15000/tokenizer_config.json
# Special tokens file saved in bert_data/test_trainer/checkpoint-15000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: text, index. If text, index are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 40000
#   Batch size = 8
# Saving model checkpoint to bert_data/test_trainer/checkpoint-20000
# Configuration saved in bert_data/test_trainer/checkpoint-20000/config.json
# Model weights saved in bert_data/test_trainer/checkpoint-20000/pytorch_model.bin
# tokenizer config file saved in bert_data/test_trainer/checkpoint-20000/tokenizer_config.json
# Special tokens file saved in bert_data/test_trainer/checkpoint-20000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: text, index. If text, index are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 40000
#   Batch size = 8
# Saving model checkpoint to bert_data/test_trainer/checkpoint-25000
# Configuration saved in bert_data/test_trainer/checkpoint-25000/config.json
# Model weights saved in bert_data/test_trainer/checkpoint-25000/pytorch_model.bin
# tokenizer config file saved in bert_data/test_trainer/checkpoint-25000/tokenizer_config.json
# Special tokens file saved in bert_data/test_trainer/checkpoint-25000/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from bert_data/test_trainer/checkpoint-25000 (score: 0.878675).
# The following columns in the test set don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: text, index. If text, index are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 40000
#   Batch size = 8
#     <div>
#
#       <progress value='5000' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5000/5000 01:36]
#     </div>

# %%
model.save_pretrained('model-twitter')
# Out:
# Configuration saved in model-twitter/config.json
# Model weights saved in model-twitter/pytorch_model.bin
